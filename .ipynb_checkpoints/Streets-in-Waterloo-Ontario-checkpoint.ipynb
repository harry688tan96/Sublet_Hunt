# %% [markdown]
# # Simple script to calculate the distance between the streets in Waterloo and the location of the University of Waterloo

# %%
from geopy.geocoders import GoogleV3
from geopy.distance import vincenty
from geopy.exc import GeocoderTimedOut, GeocoderQuotaExceeded
from multiprocessing import Pool

import pandas as pd
import time
import sys

# %% [markdown]
# #### A list of street names in Waterloo, Ontario can be found here: https://geographic.org/streetview/canada/on/city_of_waterloo.html
# The list of street names are already saved in a file named ** Waterloo_Street.txt ** in the ** data ** directory.

# %%
waterloo_street = pd.read_csv("./data/Waterloo_Street.txt")
waterloo_street["address"] = waterloo_street["street name"].apply(lambda str: str + ", Waterloo, Ontario, Canada")

waterloo_street
# Out:
#                street name                                           address
# 0         Abbotswood Court       Abbotswood Court, Waterloo, Ontario, Canada
# 1            Aberdeen Road          Aberdeen Road, Waterloo, Ontario, Canada
# 2         Academy Crescent       Academy Crescent, Waterloo, Ontario, Canada
# 3             Acadia Court           Acadia Court, Waterloo, Ontario, Canada
# 4          Ainsworth Court        Ainsworth Court, Waterloo, Ontario, Canada
# 5            Albert Street          Albert Street, Waterloo, Ontario, Canada
# 6         Alexandra Avenue       Alexandra Avenue, Waterloo, Ontario, Canada
# 7           Alexmuir Place         Alexmuir Place, Waterloo, Ontario, Canada
# 8          Algonquin Drive        Algonquin Drive, Waterloo, Ontario, Canada
# 9        Allen Street East      Allen Street East, Waterloo, Ontario, Canada
# 10       Allen Street West      Allen Street West, Waterloo, Ontario, Canada
# 11           Allenby Court          Allenby Court, Waterloo, Ontario, Canada
# 12           Allison Court          Allison Court, Waterloo, Ontario, Canada
# 13        Altheim Crescent       Altheim Crescent, Waterloo, Ontario, Canada
# 14           Altheim Place          Altheim Place, Waterloo, Ontario, Canada
# 15            Alvin Street           Alvin Street, Waterloo, Ontario, Canada
# 16             Amberg Lane            Amberg Lane, Waterloo, Ontario, Canada
# 17         Amberwood Drive        Amberwood Drive, Waterloo, Ontario, Canada
# 18         Ambleside Court        Ambleside Court, Waterloo, Ontario, Canada
# 19   American Beech Avenue  American Beech Avenue, Waterloo, Ontario, Canada
# 20             Amos Avenue            Amos Avenue, Waterloo, Ontario, Canada
# 21          Anatolin Place         Anatolin Place, Waterloo, Ontario, Canada
# 22              Angler Way             Angler Way, Waterloo, Ontario, Canada
# 23             Anita Court            Anita Court, Waterloo, Ontario, Canada
# 24         Annapolis Court        Annapolis Court, Waterloo, Ontario, Canada
# 25           Anndale Court          Anndale Court, Waterloo, Ontario, Canada
# 26            Anndale Road           Anndale Road, Waterloo, Ontario, Canada
# 27            Apache Drive           Apache Drive, Waterloo, Ontario, Canada
# 28      Appledale Crescent     Appledale Crescent, Waterloo, Ontario, Canada
# 29         Applegate Court        Applegate Court, Waterloo, Ontario, Canada
# ..                     ...                                               ...
# 847   Winder Heights Place   Winder Heights Place, Waterloo, Ontario, Canada
# 848         Windjammer Way         Windjammer Way, Waterloo, Ontario, Canada
# 849        Winfield Avenue        Winfield Avenue, Waterloo, Ontario, Canada
# 850         Wingrove Court         Wingrove Court, Waterloo, Ontario, Canada
# 851     Winterberry Avenue     Winterberry Avenue, Waterloo, Ontario, Canada
# 852       Winterburg Court       Winterburg Court, Waterloo, Ontario, Canada
# 853        Winterburg Walk        Winterburg Walk, Waterloo, Ontario, Canada
# 854      Wintergreen Drive      Wintergreen Drive, Waterloo, Ontario, Canada
# 855          Wismer Street          Wismer Street, Waterloo, Ontario, Canada
# 856           Wissler Road           Wissler Road, Waterloo, Ontario, Canada
# 857        Wood Nettle Way        Wood Nettle Way, Waterloo, Ontario, Canada
# 858      Woodbend Crescent      Woodbend Crescent, Waterloo, Ontario, Canada
# 859       Woodington Place       Woodington Place, Waterloo, Ontario, Canada
# 860         Woodlawn Place         Woodlawn Place, Waterloo, Ontario, Canada
# 861          Woodrow Drive          Woodrow Drive, Waterloo, Ontario, Canada
# 862          Woodrow Place          Woodrow Place, Waterloo, Ontario, Canada
# 863        Woodville Place        Woodville Place, Waterloo, Ontario, Canada
# 864       Woolgrass Avenue       Woolgrass Avenue, Waterloo, Ontario, Canada
# 865         Woolwich Place         Woolwich Place, Waterloo, Ontario, Canada
# 866        Woolwich Street        Woolwich Street, Waterloo, Ontario, Canada
# 867  Woolwich Street North  Woolwich Street North, Waterloo, Ontario, Canada
# 868     Wyecroft Boulevard     Wyecroft Boulevard, Waterloo, Ontario, Canada
# 869             Wyman Road             Wyman Road, Waterloo, Ontario, Canada
# 870         Yarmouth Drive         Yarmouth Drive, Waterloo, Ontario, Canada
# 871            York Street            York Street, Waterloo, Ontario, Canada
# 872        Yorkshire Drive        Yorkshire Drive, Waterloo, Ontario, Canada
# 873      Young Street East      Young Street East, Waterloo, Ontario, Canada
# 874      Young Street West      Young Street West, Waterloo, Ontario, Canada
# 875          Zermatt Drive          Zermatt Drive, Waterloo, Ontario, Canada
# 876           Zurich Drive           Zurich Drive, Waterloo, Ontario, Canada
#
# [877 rows x 2 columns]

# %% [markdown]
# ## Calculate distance for each of the data
# Vincenty's formulae is used to calculate the distance (km) between the street in Waterloo and the location of the University of Waterloo.

# %%
def calculate_distance(address):
    geolocator = GoogleV3() # Google Maps API
    
    try:
        housing = geolocator.geocode(address, timeout=10)
        housing_coordinates = (housing.latitude, housing.longitude)
    
    except GeocoderTimedOut:
        return calculate_distance(address)
    
    except GeocoderQuotaExceeded:
        # Google Maps (standard API) only allows:
        #     1.) 2,500 free requests per day, calculated as the sum of client-side and server-side queries.
        #     2.) 50 requests per second, calculated as the sum of client-side and server-side queries.
        return calculate_distance(address)
    
    except:
        print ("Unexpected error:", sys.exc_info()[0])  # Hack to check the type of exception thrown by Geocoder
        return "Error: Could not find the coordinates for address: %s" % address

    UW_coordinates = (43.469757, -80.5409518)
    
    distance = vincenty(housing_coordinates, UW_coordinates).kilometers
    return round(distance, 3)

# %% [markdown]
# Here, we utilize the benefit of multiprocessing. First, we slice the dataframe into few chunks (ie. each chunk of size 10). Then, we apply the * calculate_distance * function on these chunks concurrently using multiple processors. There is a ** 10x ** speed faster using multiprocessing.

# %%
###### Apply function on DataFrame in parallel Using Multiprocessing #######
# https://stackoverflow.com/questions/26187759/parallelize-apply-after-pandas-groupby/29281494#29281494

process_num = 20

def applyParallel(dfGrouped, func):
    grouped_list = [group for _, group in dfGrouped]
    
    with Pool(processes=process_num) as p:
        ret_list = p.map(func, grouped_list)
        p.close()
        p.join()
    return pd.concat(ret_list)

def apply_row_df(df):
    df["distance (km)"] =  df['address'].apply(calculate_distance)
    return df

grouped = waterloo_street.groupby(waterloo_street.index // 10) # Partition into chunks of size 10

tic = time.time()
waterloo_street = applyParallel(grouped, apply_row_df)
toc = time.time()

print("Total execution time using multiprocessing:  {}s".format(toc - tic))
# Out:
# Total execution time using multiprocessing:  95.18907070159912s

# %% [markdown]
# #### Ignore waterloo streets that are too far from the University of Waterloo (i.e. distance that is > 2.5). Sort the data according to the distance.

# %%
waterloo_street = waterloo_street[waterloo_street["distance (km)"]<=2.5]
nearby_street = waterloo_street.sort_values("distance (km)")

nearby_street
# Out:
#                         street name  \
# 645                       Ring Road
# 688                   Seagram Drive
# 406                  Iroquois Place
# 762                  Tennyson Place
# 453                   Lester Street
# 548               North Campus Road
# 8                   Algonquin Drive
# 696               Shakespeare Place
# 752                  Sunview Street
# 466                Longfellow Drive
# 27                     Apache Drive
# 765                  The Lions Gate
# 461                     Lions Court
# 811                 Westcourt Place
# 298        Father David Bauer Drive
# 596                  Phillip Street
# 695               Shakespeare Drive
# 521                   Mohawk Avenue
# 55                    Batavia Place
# 751                 Sunshine Avenue
# 5                     Albert Street
# 377                  Hemlock Street
# 316               Frank Tompa Drive
# 570                   Old Post Road
# 420                 Keats Way Place
# 614                 Post Horn Place
# 172                  Central Street
# 658             Roslin Avenue North
# 250              Dietz Avenue North
# 49                    Balsam Street
# ..                              ...
# 85               Blue Springs Drive
# 17                  Amberwood Drive
# 863                 Woodville Place
# 465                    Lonelm Place
# 159                   Carter Avenue
# 99                  Box Grove Place
# 190                  Claywood Court
# 334                Glenelm Crescent
# 426  King Street North Service Road
# 492             Martindale Crescent
# 394                  Homeview Place
# 108                 Branstone Drive
# 431                 Kingsmill Court
# 622                   Ralston Place
# 252                  Dixie Crescent
# 581                 Park Lawn Place
# 684                 Schaefer Street
# 324             Gatestone Boulevard
# 598             Pine Grove Crescent
# 525              Moore Avenue South
# 682               Sandy Ridge Place
# 797                Warrington Drive
# 260                    Dover Street
# 530                Mount Anne Drive
# 306      Fischer Hallman Road South
# 330            Glen Manor Boulevard
# 473              Lynnbrook Crescent
# 296              Fallingbrook Drive
# 50                  Baringham Place
# 7                    Alexmuir Place
#
#                                                address  distance (km)
# 645               Ring Road, Waterloo, Ontario, Canada          0.283
# 688           Seagram Drive, Waterloo, Ontario, Canada          0.534
# 406          Iroquois Place, Waterloo, Ontario, Canada          0.638
# 762          Tennyson Place, Waterloo, Ontario, Canada          0.660
# 453           Lester Street, Waterloo, Ontario, Canada          0.696
# 548       North Campus Road, Waterloo, Ontario, Canada          0.741
# 8           Algonquin Drive, Waterloo, Ontario, Canada          0.749
# 696       Shakespeare Place, Waterloo, Ontario, Canada          0.757
# 752          Sunview Street, Waterloo, Ontario, Canada          0.764
# 466        Longfellow Drive, Waterloo, Ontario, Canada          0.766
# 27             Apache Drive, Waterloo, Ontario, Canada          0.775
# 765          The Lions Gate, Waterloo, Ontario, Canada          0.855
# 461             Lions Court, Waterloo, Ontario, Canada          0.866
# 811         Westcourt Place, Waterloo, Ontario, Canada          0.896
